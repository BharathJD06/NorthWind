# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("orderdetails.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of      Order_ID            Date Cust_First Cust_Last Customer_Company  \
# 0           1  4/6/2026 11:47      James    Dalton      Alpha Group
# 1           2  4/6/2026 12:47      James    Dalton      Alpha Group
# 2           3  4/6/2026 13:47      James    Dalton      Alpha Group
# 3           4  4/6/2026 14:47      James    Dalton      Alpha Group
# 4           5  4/6/2026 15:47      James    Dalton      Alpha Group
# ..        ...             ...        ...       ...              ...
# 195       196  4/2/2026 17:47     Zenebe     Abebe    Northern Star
# 196       197  4/3/2026 13:47     Zenebe     Abebe    Northern Star
# 197       198   4/4/2026 9:47     Zenebe     Abebe    Northern Star
# 198       199   4/5/2026 5:47     Zenebe     Abebe    Northern Star
# 199       200   4/6/2026 1:47     Zenebe     Abebe    Northern Star
#
#      Sales_Rep           Product  Qty  Price  Line_Total Order_Status
# 0    Alexander         Green Tea   20   15.5       310.0       Closed
# 1         Anne           Ravioli   18   15.5       279.0          New
# 2        Laura             Bread   11   15.5       170.5      Shipped
# 3       Robert         Green Tea   40   15.5       620.0       Closed
# 4      Michael  Chef Anton Gumbo   10   15.5       155.0     Invoiced
# ..         ...               ...  ...    ...         ...          ...
# 195     Steven  Boston Crab Meat   38   15.5       589.0          New
# 196     Mariya           Ravioli   11   15.5       170.5       Closed
# 197        Jan            Coffee   10   15.5       155.0     Invoiced
# 198     Andrew       Dried Fruit    9   15.5       139.5          New
# 199      Nancy              Tofu   11   15.5       170.5          New
#
# [200 rows x 11 columns]>

# %%
df.head()
# Out:
#    Order_ID            Date Cust_First Cust_Last Customer_Company  Sales_Rep  \
# 0         1  4/6/2026 11:47      James    Dalton      Alpha Group  Alexander
# 1         2  4/6/2026 12:47      James    Dalton      Alpha Group       Anne
# 2         3  4/6/2026 13:47      James    Dalton      Alpha Group      Laura
# 3         4  4/6/2026 14:47      James    Dalton      Alpha Group     Robert
# 4         5  4/6/2026 15:47      James    Dalton      Alpha Group    Michael
#
#             Product  Qty  Price  Line_Total Order_Status
# 0         Green Tea   20   15.5       310.0       Closed
# 1           Ravioli   18   15.5       279.0          New
# 2             Bread   11   15.5       170.5      Shipped
# 3         Green Tea   40   15.5       620.0       Closed
# 4  Chef Anton Gumbo   10   15.5       155.0     Invoiced

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Order_ID            Date Cust_First Cust_Last Customer_Company  \
# 0           1  4/6/2026 11:47      James    Dalton      Alpha Group
# 1           2  4/6/2026 12:47      James    Dalton      Alpha Group
# 2           3  4/6/2026 13:47      James    Dalton      Alpha Group
# 3           4  4/6/2026 14:47      James    Dalton      Alpha Group
# 4           5  4/6/2026 15:47      James    Dalton      Alpha Group
# ..        ...             ...        ...       ...              ...
# 195       196  4/2/2026 17:47     Zenebe     Abebe    Northern Star
# 196       197  4/3/2026 13:47     Zenebe     Abebe    Northern Star
# 197       198   4/4/2026 9:47     Zenebe     Abebe    Northern Star
# 198       199   4/5/2026 5:47     Zenebe     Abebe    Northern Star
# 199       200   4/6/2026 1:47     Zenebe     Abebe    Northern Star
#
#      Sales_Rep           Product  Qty  Price  Line_Total Order_Status
# 0    Alexander         Green Tea   20   15.5       310.0       Closed
# 1         Anne           Ravioli   18   15.5       279.0          New
# 2        Laura             Bread   11   15.5       170.5      Shipped
# 3       Robert         Green Tea   40   15.5       620.0       Closed
# 4      Michael  Chef Anton Gumbo   10   15.5       155.0     Invoiced
# ..         ...               ...  ...    ...         ...          ...
# 195     Steven  Boston Crab Meat   38   15.5       589.0          New
# 196     Mariya           Ravioli   11   15.5       170.5       Closed
# 197        Jan            Coffee   10   15.5       155.0     Invoiced
# 198     Andrew       Dried Fruit    9   15.5       139.5          New
# 199      Nancy              Tofu   11   15.5       170.5          New
#
# [200 rows x 11 columns]>

# %%
df.shape
# Out:
# (200, 11)

# %%
print("Dataset Loaded Sucessfully, Ready for further Analysis")
# Out:
# Dataset Loaded Sucessfully, Ready for further Analysis

# %%
print("🔹 Column Names:")
print(df.columns, "\n")
# Out:
# 🔹 Column Names:
# Index(['Order_ID', 'Date', 'Cust_First', 'Cust_Last', 'Customer_Company',
#        'Sales_Rep', 'Product', 'Qty', 'Price', 'Line_Total', 'Order_Status'],
#       dtype='object')

# %%
print("🔹 Data Types:")
print(df.dtypes, "\n")
# Out:
# 🔹 Data Types:
# Order_ID              int64
# Date                 object
# Cust_First           object
# Cust_Last            object
# Customer_Company     object
# Sales_Rep            object
# Product              object
# Qty                   int64
# Price               float64
# Line_Total          float64
# Order_Status         object
# dtype: object

# %%
print("🔹 Missing Values:")
print(df.isnull().sum(), "\n")
# Out:
# 🔹 Missing Values:
# Order_ID            0
# Date                0
# Cust_First          0
# Cust_Last           0
# Customer_Company    0
# Sales_Rep           0
# Product             0
# Qty                 0
# Price               0
# Line_Total          0
# Order_Status        0
# dtype: int64

# %%
duplicates = df.duplicated().sum()
print(f"🔹 Duplicate Rows: {duplicates}\n")
# Out:
# 🔹 Duplicate Rows: 0

# %%
print("🔹 Statistical Summary:")
print(df.describe(), "\n")
# Out:
# 🔹 Statistical Summary:
#          Order_ID         Qty  Price  Line_Total
# count  200.000000  200.000000  200.0  200.000000
# mean   100.500000   25.075000   15.5  388.662500
# std     57.879185   14.190356    0.0  219.950519
# min      1.000000    1.000000   15.5   15.500000
# 25%     50.750000   13.000000   15.5  201.500000
# 50%    100.500000   25.000000   15.5  387.500000
# 75%    150.250000   37.000000   15.5  573.500000
# max    200.000000   50.000000   15.5  775.000000

# %%
df.describe()
# Out:
#          Order_ID         Qty  Price  Line_Total
# count  200.000000  200.000000  200.0  200.000000
# mean   100.500000   25.075000   15.5  388.662500
# std     57.879185   14.190356    0.0  219.950519
# min      1.000000    1.000000   15.5   15.500000
# 25%     50.750000   13.000000   15.5  201.500000
# 50%    100.500000   25.000000   15.5  387.500000
# 75%    150.250000   37.000000   15.5  573.500000
# max    200.000000   50.000000   15.5  775.000000

# %%
correlation = df.corr(numeric_only=True)
print("🔹 Correlation Matrix:")
print(correlation, "\n")
# Out:
# 🔹 Correlation Matrix:
#             Order_ID       Qty  Price  Line_Total
# Order_ID    1.000000 -0.095155    NaN   -0.095155
# Qty        -0.095155  1.000000    NaN    1.000000
# Price            NaN       NaN    NaN         NaN
# Line_Total -0.095155  1.000000    NaN    1.000000

# %%
# Plot Correlation Heatmap

plt.figure(figsize=(8,6))
plt.imshow(correlation, interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(correlation.columns)), correlation.columns, rotation=90)
plt.yticks(range(len(correlation.columns)), correlation.columns)
plt.title("Correlation Matrix")
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    plt.figure()
    plt.hist(df[col], bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in numeric_cols:
    plt.figure()
    plt.boxplot(df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    print(f"🔹 Unique values in {col}:")
    print(df[col].value_counts(), "\n")
# Out:
# 🔹 Unique values in Date:
# Date
# 4/5/2026 15:47     5
# 4/6/2026 9:47      5
# 4/6/2026 3:47      5
# 4/6/2026 1:47      5
# 4/5/2026 21:47     5
#                   ..
# 4/3/2026 17:47     1
# 4/4/2026 12:47     1
# 4/5/2026 7:47      1
# 4/6/2026 2:47      1
# 3/29/2026 13:47    1
# Name: count, Length: 100, dtype: int64
#
# 🔹 Unique values in Cust_First:
# Cust_First
# James     10
# Anna      10
# Bill      10
# Lee       10
# Lucia     10
# Wei       10
# Carlos    10
# Erik      10
# Elena     10
# Yuki      10
# Jack      10
# Marie     10
# Mateo     10
# Lars      10
# Dmitri    10
# Ken       10
# Liam      10
# Hans      10
# Aisha     10
# Zenebe    10
# Name: count, dtype: int64
#
# 🔹 Unique values in Cust_Last:
# Cust_Last
# Dalton        10
# Smith         10
# Jobson        10
# Patterson     10
# Vargas        10
# Zhu           10
# Gomez         10
# Olsen         10
# Bruno         10
# Sato          10
# Riley         10
# Dubois        10
# Silva         10
# Bakker        10
# Ivanov        10
# Tanaka        10
# O���Connor    10
# M��ller       10
# Khan          10
# Abebe         10
# Name: count, dtype: int64
#
# 🔹 Unique values in Customer_Company:
# Customer_Company
# Alpha Group           10
# Beta Corp             10
# Gamma Inc             10
# Delta Ltd             10
# Sigma Co              10
# Omega Tech            10
# Zeta Solutions        10
# Theta Retail          10
# Kappa Logistics       10
# Iota Manufacturing    10
# Blue Sky              10
# Green Field           10
# Red River             10
# White Mountain        10
# Silver Star           10
# Golden Gate           10
# Iron Works            10
# Steel Mill            10
# Silk Road             10
# Northern Star         10
# Name: count, dtype: int64
#
# 🔹 Unique values in Sales_Rep:
# Sales_Rep
# Alexander    20
# Anne         20
# Laura        20
# Robert       20
# Michael      20
# Steven       20
# Mariya       20
# Jan          20
# Andrew       20
# Nancy        20
# Name: count, dtype: int64
#
# 🔹 Unique values in Product:
# Product
# Ravioli             16
# Alice Mutton        15
# Chai                14
# Hot Sauce           14
# Coffee              13
# Chocolate           12
# Chef Anton Gumbo    11
# Apples              11
# Aniseed Syrup       10
# Dried Fruit          9
# Chang                9
# Green Tea            8
# Salmon               8
# Tofu                 8
# Cheese               8
# Boston Crab Meat     8
# Bread                7
# Shrimp               7
# Milk                 7
# Pears                5
# Name: count, dtype: int64
#
# 🔹 Unique values in Order_Status:
# Order_Status
# Invoiced    59
# Closed      54
# Shipped     49
# New         38
# Name: count, dtype: int64
